# %%
import csv

def main():
    f=open('q4.csv',encoding='cp949')
    data=csv.reader(f)
    header=next(data)
    
    B1=-99999999999
    L1=99999999999
    B2=-999999999999
    L2=999999999999999
    B3=-9999999999999
    L3=9999999999999
    B4=-9999999999999
    L4=99999999999999
    line1_1=""
    line1_2=""
    line2_1=""
    line2_2=""
    line3_1=""
    line3_2=""
    line4_1=""
    line4_2=""
    for row in data:
        if row[1]=="1호선" or row[1]=="2호선" or row[1]=="3호선" or row[1]=="4호선":
            row[-2]=int(row[-2])
            row[-3]=int(row[-3])
            if(row[1]=="1호선"):
                if(row[-3]+row[-2]>B1):
                    B1=row[-3]+row[-2]
                    line1_1=row[3]
                if(row[-3]+row[-2]<L1):
                    L1=row[-3]+row[-2]
                    line1_2=row[3]
                    
            elif row[1]=="2호선":
                if(row[-3]+row[-2]>B2):
                    B2=row[-3]+row[-2]
                    line2_1=row[3]
                if(row[-3]+row[-2]<L2):
                    L2=row[-3]+row[-2]
                    line2_2=row[3]
                    
            elif row[1]=="3호선":
                if(row[-3]+row[-2]>B3):
                    B3=row[-3]+row[-2]
                    line3_1=row[3]
                if(row[-3]+row[-2]<L3):
                    L3=row[-3]+row[-2]
                    line3_2=row[3]
                    
            elif row[1]=="4호선":
                if(row[-3]+row[-2]>B4):
                    B4=row[-3]+row[-2]
                    line4_1=row[3]
                if(row[-3]+row[-2]<L4):
                    L4=row[-3]+row[-2]
                    line4_2=row[3]
                
    
    f.close()
    print("***Subway Report for Seoul on March 2023***")
    print("Line1:")
    print("Busiest Station:{}({})".format(B1,line1_1))
    print("Least used Station:{}({})".format(L1,line1_2))
    print("Line2:")
    print("Busiest Station:{}({})".format(B2,line2_1))
    print("Least used Station:{}({})".format(L2,line2_2))
    print("Line3:")
    print("Busiest Station:{}({})".format(B3,line3_1))
    print("Least used Station:{}({})".format(L3,line3_2))
    print("Line4:")
    print("Busiest Station:{}({})".format(B4,line4_1))
    print("Least used Station:{}({})".format(L4,line4_2))
    
if __name__=="__main__":
    main()
# Out:
# ***Subway Report for Seoul on March 2023***
# Line1:
# Busiest Station:3084227(서울역)
# Least used Station:658566(동묘앞)
# Line2:
# Busiest Station:4690366(강남)
# Least used Station:80084(도림천)
# Line3:
# Busiest Station:2886887(고속터미널)
# Least used Station:48(충무로)
# Line4:
# Busiest Station:2286709(혜화)
# Least used Station:79916(남태령)
